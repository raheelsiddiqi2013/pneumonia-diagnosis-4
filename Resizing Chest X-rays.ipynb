# %%
image_height = 150
image_width = 150

# %%
# Preparing validation data
import glob
from pathlib import Path
import cv2

normal_cases_dir = Path('C:\\My Data\\My research\\Pneumonia Detection\\Robustness of Pneumonia Detection Model against Projected Gradient Descent Attack using Autoencoder based Detection and Correction\\pediatric pneumonia dataset\\val\\NORMAL')
pneumonia_cases_dir = Path('C:\\My Data\\My research\\Pneumonia Detection\\Robustness of Pneumonia Detection Model against Projected Gradient Descent Attack using Autoencoder based Detection and Correction\pediatric pneumonia dataset\\val\\PNEUMONIA')

normal_cases = normal_cases_dir.glob('*.jpeg')
pneumonia_cases = pneumonia_cases_dir.glob('*.jpeg')

test_data = []
test_labels = []

j=1

for img in normal_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (image_width,image_height))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite('C:\\Users\\Dell\\pediatric pneumonia dataset_resized_150_150\\val\\NORMAL\\val_normal{}.jpeg'.format(j),img) 
    j=j+1
    
i=1

for img in pneumonia_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (image_width,image_height))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite('C:\\Users\\Dell\\pediatric pneumonia dataset_resized_150_150\\val\\PNEUMONIA\\val_pneumonia{}.jpeg'.format(i),img)    
    i=i+1
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Dell\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Dell\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
normal_cases_dir = Path('C:\\My Data\\My research\\Pneumonia Detection\\Robustness of Pneumonia Detection Model against Projected Gradient Descent Attack using Autoencoder based Detection and Correction\\pediatric pneumonia dataset\\train\\NORMAL')
pneumonia_cases_dir = Path('C:\\My Data\\My research\\Pneumonia Detection\\Robustness of Pneumonia Detection Model against Projected Gradient Descent Attack using Autoencoder based Detection and Correction\pediatric pneumonia dataset\\train\\PNEUMONIA')

normal_cases = normal_cases_dir.glob('*.jpeg')
pneumonia_cases = pneumonia_cases_dir.glob('*.jpeg')

test_data = []
test_labels = []

j=1

for img in normal_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (image_width,image_height))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite('C:\\Users\\Dell\\pediatric pneumonia dataset_resized_150_150\\train\\NORMAL\\train_normal{}.jpeg'.format(j),img) 
    j=j+1
    
i=1

for img in pneumonia_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (image_width,image_height))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite('C:\\Users\\Dell\\pediatric pneumonia dataset_resized_150_150\\train\\PNEUMONIA\\train_pneumonia{}.jpeg'.format(i),img)    
    i=i+1

# %%
normal_cases_dir = Path('C:\\My Data\\My research\\Pneumonia Detection\\Robustness of Pneumonia Detection Model against Projected Gradient Descent Attack using Autoencoder based Detection and Correction\\pediatric pneumonia dataset\\test\\NORMAL')
pneumonia_cases_dir = Path('C:\\My Data\\My research\\Pneumonia Detection\\Robustness of Pneumonia Detection Model against Projected Gradient Descent Attack using Autoencoder based Detection and Correction\pediatric pneumonia dataset\\test\\PNEUMONIA')

normal_cases = normal_cases_dir.glob('*.jpeg')
pneumonia_cases = pneumonia_cases_dir.glob('*.jpeg')

test_data = []
test_labels = []

j=1

for img in normal_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (image_width,image_height))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite('C:\\Users\\Dell\\pediatric pneumonia dataset_resized_150_150\\test\\NORMAL\\test_normal{}.jpeg'.format(j),img) 
    j=j+1
    
i=1

for img in pneumonia_cases:
    img = cv2.imread(str(img))
    img = cv2.resize(img, (image_width,image_height))
    if img.shape[2] ==1:
        img = np.dstack([img, img, img])
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.imwrite('C:\\Users\\Dell\\pediatric pneumonia dataset_resized_150_150\\test\\PNEUMONIA\\test_pneumonia{}.jpeg'.format(i),img)    
    i=i+1
